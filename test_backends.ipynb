# %% [markdown]
# ### Test of the Widget Matplotlib figures
#
# In order to run the below script, you need to install `pip install ipympl`, `pip install ipython` and `pip install ipywidgets`.
#
# If using `conda`, then do `conda update -c conda-forge ipympl ipywidgets`.
#
# For $\LaTeX$ fonts perhaps install `apt-get install cm-super`
#
# Test this on Colab: https://colab.research.google.com/github/pschlatt1/notebooks/blob/main/test_backends.ipynb

# %%
import sys
IN_COLAB = 'google.colab' in sys.modules
if IN_COLAB:
  # for Google Colab and interative figures
  # !pip install -q ipympl
  from google.colab import output
  output.enable_custom_widget_manager()

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pylab as pylab
import matplotlib as mpl

# %matplotlib widget

#mpl.use('widget')

# %%
params = {'legend.fontsize': 12,
          'legend.loc':'best',
          'figure.figsize': (8,5),
          'lines.markerfacecolor':'none',
          'axes.labelsize': 12,
          'axes.titlesize': 12,
          'xtick.labelsize':12,
          'ytick.labelsize':12,
          'grid.alpha':0.6,
          'text.usetex':True}
pylab.rcParams.update(params)

# if you want LaTeX fonts:
if mpl.rcParams['text.usetex']:
  if IN_COLAB:
    # !apt install texlive-fonts-recommended texlive-fonts-extra cm-super dvipng
  mpl.rc('text', usetex=True)
  mpl.rcParams['font.family'] = 'serif'
  mpl.rcParams['font.serif'] = ['Computer Modern']

# %%
fig=plt.figure()
fig.canvas.toolbar_visible = True
fig.canvas.header_visible = False
fig.canvas.footer_visible = True

x = np.linspace(0,10,100)
y = np.sin(x)

plt.plot(x,y)
plt.title(r'$\sum_{i=0}^\infty \log x$')
plt.xlabel(r'$x$-axis')
plt.ylabel(r'$y^5$')

plt.show()
# Out:
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
z=3
