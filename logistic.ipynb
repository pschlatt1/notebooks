# %% [markdown]
# # Logistic Map
# ### Philipp Schlatter 2026, LSTM-FAU

# %%
# %matplotlib notebook
#%matplotlib widget
#%matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
params = {'legend.fontsize': 12,
          'legend.loc':'best',
          'figure.figsize': (8,5),
          'lines.markerfacecolor':'none',
          'axes.labelsize': 12,
          'axes.titlesize': 12,
          'xtick.labelsize':12,
          'ytick.labelsize':12,
          'grid.alpha':0.6,
          'text.usetex':False}
pylab.rcParams.update(params)

# %%
import numpy as np
import matplotlib.pyplot as plt

interval = (2.8, 4)  # start, end
accuracy = 0.0001
reps = 600  # number of repetitions
numtoplot = 200
lims = np.zeros(reps)

fig, biax = plt.subplots()

lims[0] = np.random.rand()
for r in np.arange(interval[0], interval[1], accuracy):
    for i in range(reps - 1):
        lims[i + 1] = r * lims[i] * (1 - lims[i])

    biax.plot([r] * numtoplot, lims[reps - numtoplot :], "b.", markersize=0.02)

biax.set(xlabel="$a$", ylabel="$x$", title="logistic map")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
r = 3.2
lims[0] = np.random.rand()
for i in range(reps - 1):
    lims[i + 1] = r * lims[i] * (1 - lims[i])
plt.figure()
plt.plot(lims)
plt.xlim(0,40)
plt.xlabel(r'$n$')
plt.ylabel(r'$x_n$')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
