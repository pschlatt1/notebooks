# %% [markdown]
# Reading and plotting the figures from Simson TS waves

# %%
# %matplotlib widget
from rwplot import showplot
import matplotlib.pyplot as plt

plt.rc('text', usetex=True)
plt.rc('font', family='serif', size=12)

# %%
fig=showplot('TS2D')
# Out:
# Loaded Matplotlib figure data V01: 58 lines
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig=showplot('TS3D')
# Out:
# Loaded Matplotlib figure data V01: 24 lines
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
